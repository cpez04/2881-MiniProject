# %%
# %pip install transformers accelerate torch sentencepiece bitsandbytes aiohttp requests --quiet together
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# label-studio 1.12.0 requires jsonschema==3.2.0, but you have jsonschema 4.23.0 which is incompatible.
# label-studio 1.12.0 requires pydantic<=1.11.0,>=1.7.3, but you have pydantic 2.10.6 which is incompatible.
# label-studio 1.12.0 requires wheel<=0.40.0,>=0.38.1, but you have wheel 0.44.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os, json, time
from together import Together

load_dotenv()
api_key = os.getenv("TOGETHER_API_KEY")

client = Together(api_key=api_key)

MODEL = "mistralai/Mistral-7B-Instruct-v0.1"

INPUT_FILE = "../data/query_data.jsonl"
OUTPUT_FILE = "../results/Mistral-Instruct-7b.jsonl"

# %%
GEN_CFG = dict(
    max_tokens=512,
    temperature=0.2,
    top_p=0.9,
    top_k=60,
    num_beams=1,
    repetition_penalty=1.0,
    stop=["</s>"],
)

# %%
def run_query(prompt: str):
    """Send one prompt to the model and return text + latency."""
    start = time.time()
    resp = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": prompt}],
        **GEN_CFG
    )
    elapsed = time.time() - start
    text = resp.choices[0].message.content if resp.choices else ""
    return text.strip(), elapsed

# %%
with open(INPUT_FILE, "r", encoding="utf-8") as fin, \
        open(OUTPUT_FILE, "w", encoding="utf-8") as fout:

    for i, line in enumerate(fin, 1):
        row = json.loads(line)

        context = row.get("context", "")
        prompt = row.get("prompt", "")
        anchor = row.get("anchor", "")
        qid = row.get("id", i)


        print(f"[{i}] id={qid} — sending prompt of length {len(prompt)} chars")

        try:
            output, latency = run_query(prompt)
            result = {
                "id": qid,
                "context": context,
                "prompt": prompt,
                "anchor": anchor,
                "output": output,
                "latency_sec": round(latency, 3),
                "model": MODEL,
            }
            fout.write(json.dumps(result, ensure_ascii=False) + "\n")
            print(f"✔ Done in {latency:.2f}s, {len(output)} chars output.")
        except Exception as e:
            print(f"✖ Error on example {i}: {e}")
            fout.write(json.dumps({
                "id": qid,
                "context": context,
                "prompt": prompt,
                "anchor": anchor,
                "error": str(e),
                "model": MODEL,
            }, ensure_ascii=False) + "\n")

print(f"\nAll queries completed. Results saved to {OUTPUT_FILE}")
# Out:
# [1] id=1 — sending prompt of length 1137 chars
# ✔ Done in 0.84s, 356 chars output.
# [2] id=2 — sending prompt of length 1695 chars
# ✔ Done in 0.56s, 367 chars output.
# [3] id=3 — sending prompt of length 1335 chars
# ✔ Done in 1.91s, 1125 chars output.
# [4] id=4 — sending prompt of length 1491 chars
# ✔ Done in 0.69s, 450 chars output.
# [5] id=5 — sending prompt of length 1546 chars
# ✔ Done in 2.20s, 1742 chars output.
# [6] id=6 — sending prompt of length 1514 chars
# ✔ Done in 1.42s, 874 chars output.
# [7] id=7 — sending prompt of length 1411 chars
# ✔ Done in 0.50s, 233 chars output.
# [8] id=8 — sending prompt of length 1349 chars
# ✔ Done in 0.86s, 547 chars output.
# [9] id=9 — sending prompt of length 1356 chars
# ✔ Done in 1.23s, 732 chars output.
# [10] id=10 — sending prompt of length 1468 chars
# ✔ Done in 0.62s, 371 chars output.
# [11] id=11 — sending prompt of length 1279 chars
# ✔ Done in 0.89s, 610 chars output.
# [12] id=12 — sending prompt of length 1218 chars
# ✔ Done in 1.45s, 853 chars output.
# [13] id=13 — sending prompt of length 1416 chars
# ✔ Done in 1.57s, 1212 chars output.
# [14] id=14 — sending prompt of length 1259 chars
# ✔ Done in 1.05s, 690 chars output.
# [15] id=15 — sending prompt of length 1321 chars
# ✔ Done in 1.60s, 1097 chars output.
# [16] id=16 — sending prompt of length 1570 chars
# ✔ Done in 1.02s, 741 chars output.
# [17] id=17 — sending prompt of length 1391 chars
# ✔ Done in 1.59s, 1193 chars output.
# [18] id=18 — sending prompt of length 1378 chars
# ✔ Done in 1.03s, 675 chars output.
# [19] id=19 — sending prompt of length 1389 chars
# ✔ Done in 0.31s, 82 chars output.
# [20] id=20 — sending prompt of length 1279 chars
# ✔ Done in 0.96s, 513 chars output.
# [21] id=21 — sending prompt of length 1365 chars
# ✔ Done in 1.61s, 1205 chars output.
# [22] id=22 — sending prompt of length 1445 chars
# ✔ Done in 1.86s, 1363 chars output.
# [23] id=23 — sending prompt of length 1322 chars
# ✔ Done in 1.18s, 831 chars output.
# [24] id=24 — sending prompt of length 1394 chars
# ✔ Done in 1.57s, 1204 chars output.
# [25] id=25 — sending prompt of length 1264 chars
# ✔ Done in 1.53s, 1053 chars output.
# [26] id=26 — sending prompt of length 1353 chars
# ✔ Done in 1.58s, 1213 chars output.
# [27] id=27 — sending prompt of length 1388 chars
# ✔ Done in 1.46s, 1063 chars output.
# [28] id=28 — sending prompt of length 1064 chars
# ✔ Done in 1.57s, 974 chars output.
# [29] id=29 — sending prompt of length 1280 chars
# ✔ Done in 0.52s, 218 chars output.
# [30] id=30 — sending prompt of length 1282 chars
# ✔ Done in 0.57s, 257 chars output.
# [31] id=31 — sending prompt of length 1511 chars
# ✔ Done in 1.27s, 931 chars output.
# [32] id=32 — sending prompt of length 1435 chars
# ✔ Done in 1.67s, 1242 chars output.
# [33] id=33 — sending prompt of length 1188 chars
# ✔ Done in 0.49s, 206 chars output.
# [34] id=34 — sending prompt of length 1389 chars
# ✔ Done in 0.76s, 415 chars output.
# [35] id=35 — sending prompt of length 1443 chars
# ✔ Done in 0.91s, 708 chars output.
# [36] id=36 — sending prompt of length 1244 chars
# ✔ Done in 0.96s, 693 chars output.
# [37] id=37 — sending prompt of length 1321 chars
# ✔ Done in 1.76s, 1136 chars output.
# [38] id=38 — sending prompt of length 1422 chars
# ✔ Done in 1.70s, 1239 chars output.
# [39] id=39 — sending prompt of length 1366 chars
# ✔ Done in 1.67s, 1180 chars output.
# [40] id=40 — sending prompt of length 1305 chars
# ✔ Done in 1.87s, 1116 chars output.
# [41] id=41 — sending prompt of length 1313 chars
# ✔ Done in 0.36s, 75 chars output.
# [42] id=42 — sending prompt of length 1223 chars
# ✔ Done in 1.93s, 1212 chars output.
# [43] id=43 — sending prompt of length 1244 chars
# ✔ Done in 1.24s, 974 chars output.
# [44] id=44 — sending prompt of length 1376 chars
# ✔ Done in 1.38s, 1124 chars output.
# [45] id=45 — sending prompt of length 1223 chars
# ✔ Done in 0.49s, 248 chars output.
# [46] id=46 — sending prompt of length 1227 chars
# ✔ Done in 1.09s, 625 chars output.
# [47] id=47 — sending prompt of length 1378 chars
# ✔ Done in 1.57s, 1208 chars output.
# [48] id=48 — sending prompt of length 1206 chars
# ✔ Done in 1.57s, 764 chars output.
# [49] id=49 — sending prompt of length 1457 chars
# ✔ Done in 1.61s, 1298 chars output.
# [50] id=50 — sending prompt of length 1444 chars
# ✔ Done in 1.53s, 1126 chars output.
# [51] id=51 — sending prompt of length 1350 chars
# ✔ Done in 1.57s, 1109 chars output.
# [52] id=52 — sending prompt of length 1145 chars
# ✔ Done in 0.61s, 292 chars output.
# [53] id=53 — sending prompt of length 1208 chars
# ✔ Done in 1.01s, 584 chars output.
# [54] id=54 — sending prompt of length 875 chars
# ✔ Done in 1.52s, 694 chars output.
# [55] id=55 — sending prompt of length 1420 chars
# ✔ Done in 1.26s, 904 chars output.
# [56] id=56 — sending prompt of length 1346 chars
# ✔ Done in 0.72s, 561 chars output.
# [57] id=57 — sending prompt of length 1329 chars
# ✔ Done in 1.75s, 1143 chars output.
# [58] id=58 — sending prompt of length 1402 chars
# ✔ Done in 1.69s, 1223 chars output.
# [59] id=59 — sending prompt of length 1407 chars
# ✔ Done in 1.54s, 1221 chars output.
# [60] id=60 — sending prompt of length 1352 chars
# ✔ Done in 1.77s, 1182 chars output.
# [61] id=61 — sending prompt of length 1389 chars
# ✔ Done in 1.76s, 1209 chars output.
# [62] id=62 — sending prompt of length 1330 chars
# ✔ Done in 1.28s, 826 chars output.
# [63] id=63 — sending prompt of length 1439 chars
# ✔ Done in 0.82s, 566 chars output.
# [64] id=64 — sending prompt of length 1417 chars
# ✔ Done in 0.67s, 382 chars output.
# [65] id=65 — sending prompt of length 1301 chars
# ✔ Done in 0.95s, 502 chars output.
# [66] id=66 — sending prompt of length 1293 chars
# ✔ Done in 1.69s, 1127 chars output.
# [67] id=67 — sending prompt of length 1411 chars
# ✔ Done in 1.63s, 1179 chars output.
# [68] id=68 — sending prompt of length 1126 chars
# ✔ Done in 0.65s, 257 chars output.
# [69] id=69 — sending prompt of length 1354 chars
# ✔ Done in 1.76s, 1317 chars output.
# [70] id=70 — sending prompt of length 1215 chars
# ✔ Done in 1.20s, 646 chars output.
# [71] id=71 — sending prompt of length 1486 chars
# ✔ Done in 0.78s, 488 chars output.
# [72] id=72 — sending prompt of length 920 chars
# ✔ Done in 1.14s, 723 chars output.
# [73] id=73 — sending prompt of length 1526 chars
# ✔ Done in 1.48s, 1223 chars output.
# [74] id=74 — sending prompt of length 1209 chars
# ✔ Done in 2.24s, 1102 chars output.
# [75] id=75 — sending prompt of length 1369 chars
# ✔ Done in 1.85s, 1322 chars output.
# [76] id=76 — sending prompt of length 1344 chars
# ✔ Done in 1.23s, 790 chars output.
# [77] id=77 — sending prompt of length 1374 chars
# ✔ Done in 1.59s, 819 chars output.
# [78] id=78 — sending prompt of length 1081 chars
# ✔ Done in 1.40s, 885 chars output.
# [79] id=79 — sending prompt of length 1403 chars
# ✔ Done in 1.91s, 1243 chars output.
# [80] id=80 — sending prompt of length 1287 chars
# ✔ Done in 1.53s, 1000 chars output.
# [81] id=81 — sending prompt of length 1192 chars
# ✔ Done in 1.48s, 893 chars output.
# [82] id=82 — sending prompt of length 1464 chars
# ✔ Done in 1.13s, 829 chars output.
# [83] id=83 — sending prompt of length 1368 chars
# ✔ Done in 2.83s, 2426 chars output.
# [84] id=84 — sending prompt of length 1504 chars
# ✔ Done in 1.72s, 1384 chars output.
# [85] id=85 — sending prompt of length 1250 chars
# ✔ Done in 1.17s, 699 chars output.
# [86] id=86 — sending prompt of length 1454 chars
# ✔ Done in 1.57s, 1085 chars output.
# [87] id=87 — sending prompt of length 1191 chars
# ✔ Done in 1.43s, 824 chars output.
# [88] id=88 — sending prompt of length 1273 chars
# ✔ Done in 1.44s, 926 chars output.
# [89] id=89 — sending prompt of length 887 chars
# ✔ Done in 1.11s, 692 chars output.
# [90] id=90 — sending prompt of length 1321 chars
# ✔ Done in 1.54s, 1131 chars output.
# [91] id=91 — sending prompt of length 1281 chars
# ✔ Done in 0.23s, 65 chars output.
# [92] id=92 — sending prompt of length 1475 chars
# ✔ Done in 1.68s, 1333 chars output.
# [93] id=93 — sending prompt of length 1284 chars
# ✔ Done in 3.11s, 1494 chars output.
# [94] id=94 — sending prompt of length 1240 chars
# ✔ Done in 0.82s, 474 chars output.
# [95] id=95 — sending prompt of length 1436 chars
# ✔ Done in 1.62s, 1170 chars output.
# [96] id=96 — sending prompt of length 1251 chars
# ✔ Done in 0.74s, 424 chars output.
# [97] id=97 — sending prompt of length 1335 chars
# ✔ Done in 0.50s, 248 chars output.
# [98] id=98 — sending prompt of length 1399 chars
# ✔ Done in 1.05s, 838 chars output.
# [99] id=99 — sending prompt of length 1411 chars
# ✔ Done in 0.72s, 570 chars output.
# [100] id=100 — sending prompt of length 1213 chars
# ✔ Done in 1.57s, 983 chars output.
# [101] id=101 — sending prompt of length 1239 chars
# ✔ Done in 0.86s, 474 chars output.
# [102] id=102 — sending prompt of length 1152 chars
# ✔ Done in 0.90s, 335 chars output.
# [103] id=103 — sending prompt of length 1441 chars
# ✔ Done in 0.85s, 589 chars output.
# [104] id=104 — sending prompt of length 1204 chars
# ✔ Done in 0.81s, 619 chars output.
# [105] id=105 — sending prompt of length 1378 chars
# ✔ Done in 0.76s, 629 chars output.
# [106] id=106 — sending prompt of length 1249 chars
# ✔ Done in 1.24s, 821 chars output.
# [107] id=107 — sending prompt of length 1330 chars
# ✔ Done in 1.95s, 1151 chars output.
# [108] id=108 — sending prompt of length 1310 chars
# ✔ Done in 1.59s, 1128 chars output.
# [109] id=109 — sending prompt of length 1231 chars
# ✔ Done in 1.73s, 1098 chars output.
# [110] id=110 — sending prompt of length 1332 chars
# ✔ Done in 0.83s, 596 chars output.
# [111] id=111 — sending prompt of length 1521 chars
# ✔ Done in 1.06s, 884 chars output.
# [112] id=112 — sending prompt of length 1388 chars
# ✔ Done in 0.24s, 55 chars output.
# [113] id=113 — sending prompt of length 1416 chars
# ✔ Done in 2.28s, 1938 chars output.
# [114] id=114 — sending prompt of length 1488 chars
# ✔ Done in 1.91s, 1489 chars output.
# [115] id=115 — sending prompt of length 1238 chars
# ✔ Done in 0.91s, 476 chars output.
# [116] id=116 — sending prompt of length 1364 chars
# ✔ Done in 1.75s, 1466 chars output.
# [117] id=117 — sending prompt of length 1459 chars
# ✔ Done in 0.62s, 430 chars output.
# [118] id=118 — sending prompt of length 1407 chars
# ✔ Done in 1.20s, 949 chars output.
# [119] id=119 — sending prompt of length 1267 chars
# ✔ Done in 1.61s, 1112 chars output.
# [120] id=120 — sending prompt of length 1140 chars
# ✔ Done in 1.54s, 882 chars output.
# [121] id=121 — sending prompt of length 1456 chars
# ✔ Done in 1.21s, 1016 chars output.
# [122] id=122 — sending prompt of length 1406 chars
# ✔ Done in 0.88s, 569 chars output.
# [123] id=123 — sending prompt of length 1267 chars
# ✔ Done in 1.67s, 1141 chars output.
# [124] id=124 — sending prompt of length 1532 chars
# ✔ Done in 2.24s, 1793 chars output.
# [125] id=125 — sending prompt of length 1274 chars
# ✔ Done in 1.16s, 721 chars output.
# [126] id=126 — sending prompt of length 1500 chars
# ✔ Done in 2.09s, 1916 chars output.
# [127] id=127 — sending prompt of length 1366 chars
# ✔ Done in 1.59s, 1196 chars output.
# [128] id=128 — sending prompt of length 1253 chars
# ✔ Done in 1.83s, 1068 chars output.
# [129] id=129 — sending prompt of length 1363 chars
# ✔ Done in 1.66s, 1394 chars output.
# [130] id=130 — sending prompt of length 1472 chars
# ✔ Done in 1.66s, 1349 chars output.
# [131] id=131 — sending prompt of length 1293 chars
# ✔ Done in 1.57s, 1160 chars output.
# [132] id=132 — sending prompt of length 1230 chars
# ✔ Done in 1.06s, 536 chars output.
# [133] id=133 — sending prompt of length 1217 chars
# ✔ Done in 0.77s, 471 chars output.
# [134] id=134 — sending prompt of length 1403 chars
# ✔ Done in 0.53s, 239 chars output.
# [135] id=135 — sending prompt of length 1335 chars
# ✔ Done in 0.89s, 633 chars output.
# [136] id=136 — sending prompt of length 1209 chars
# ✔ Done in 0.82s, 505 chars output.
# [137] id=137 — sending prompt of length 1200 chars
# ✔ Done in 1.97s, 1368 chars output.
# [138] id=138 — sending prompt of length 1322 chars
# ✔ Done in 1.61s, 1148 chars output.
# [139] id=139 — sending prompt of length 1417 chars
# ✔ Done in 1.71s, 1242 chars output.
# [140] id=140 — sending prompt of length 1228 chars
# ✔ Done in 0.68s, 387 chars output.
# [141] id=141 — sending prompt of length 1411 chars
# ✔ Done in 1.94s, 1208 chars output.
# [142] id=142 — sending prompt of length 1497 chars
# ✔ Done in 1.05s, 797 chars output.
# [143] id=143 — sending prompt of length 1293 chars
# ✔ Done in 1.38s, 919 chars output.
# [144] id=144 — sending prompt of length 1562 chars
# ✔ Done in 1.57s, 1245 chars output.
# [145] id=145 — sending prompt of length 1308 chars
# ✔ Done in 0.87s, 463 chars output.
# [146] id=146 — sending prompt of length 1400 chars
# ✔ Done in 2.68s, 2140 chars output.
# [147] id=147 — sending prompt of length 1554 chars
# ✔ Done in 1.70s, 1399 chars output.
# [148] id=148 — sending prompt of length 1401 chars
# ✔ Done in 0.52s, 265 chars output.
# [149] id=149 — sending prompt of length 1367 chars
# ✔ Done in 1.62s, 1199 chars output.
# [150] id=150 — sending prompt of length 1355 chars
# ✔ Done in 1.70s, 1053 chars output.
# [151] id=151 — sending prompt of length 1297 chars
# ✔ Done in 0.95s, 583 chars output.
# [152] id=152 — sending prompt of length 1444 chars
# ✔ Done in 1.50s, 1206 chars output.
# [153] id=153 — sending prompt of length 1208 chars
# ✔ Done in 1.56s, 985 chars output.
# [154] id=154 — sending prompt of length 1392 chars
# ✔ Done in 1.57s, 1195 chars output.
# [155] id=155 — sending prompt of length 1236 chars
# ✔ Done in 1.73s, 1074 chars output.
# [156] id=156 — sending prompt of length 1323 chars
# ✔ Done in 1.51s, 1157 chars output.
# [157] id=157 — sending prompt of length 1440 chars
# ✔ Done in 0.99s, 812 chars output.
# [158] id=158 — sending prompt of length 1399 chars
# ✔ Done in 1.63s, 1013 chars output.
# [159] id=159 — sending prompt of length 1397 chars
# ✔ Done in 0.71s, 518 chars output.
# [160] id=160 — sending prompt of length 1396 chars
# ✔ Done in 1.60s, 1219 chars output.
# [161] id=161 — sending prompt of length 1360 chars
# ✔ Done in 1.09s, 830 chars output.
# [162] id=162 — sending prompt of length 963 chars
# ✔ Done in 1.76s, 793 chars output.
# [163] id=163 — sending prompt of length 1238 chars
# ✔ Done in 1.04s, 523 chars output.
# [164] id=164 — sending prompt of length 1286 chars
# ✔ Done in 0.69s, 256 chars output.
# [165] id=165 — sending prompt of length 1318 chars
# ✔ Done in 0.53s, 301 chars output.
# [166] id=166 — sending prompt of length 1262 chars
# ✔ Done in 1.60s, 1058 chars output.
# [167] id=167 — sending prompt of length 1480 chars
# ✔ Done in 1.67s, 1314 chars output.
# [168] id=168 — sending prompt of length 1444 chars
# ✔ Done in 0.95s, 646 chars output.
# [169] id=169 — sending prompt of length 1394 chars
# ✔ Done in 1.38s, 1167 chars output.
# [170] id=170 — sending prompt of length 1352 chars
# ✔ Done in 0.79s, 496 chars output.
# [171] id=171 — sending prompt of length 1484 chars
# ✔ Done in 2.35s, 1991 chars output.
# [172] id=172 — sending prompt of length 1458 chars
# ✔ Done in 1.31s, 1058 chars output.
# [173] id=173 — sending prompt of length 1500 chars
# ✔ Done in 1.83s, 1381 chars output.
# [174] id=174 — sending prompt of length 1453 chars
# ✔ Done in 1.60s, 1270 chars output.
# [175] id=175 — sending prompt of length 1505 chars
# ✔ Done in 0.65s, 438 chars output.
# [176] id=176 — sending prompt of length 1298 chars
# ✔ Done in 1.62s, 1132 chars output.
# [177] id=177 — sending prompt of length 1326 chars
# ✔ Done in 1.53s, 1143 chars output.
# [178] id=178 — sending prompt of length 1233 chars
# ✔ Done in 0.88s, 474 chars output.
# [179] id=179 — sending prompt of length 1235 chars
# ✔ Done in 1.65s, 1086 chars output.
# [180] id=180 — sending prompt of length 1255 chars
# ✔ Done in 1.07s, 703 chars output.
# [181] id=181 — sending prompt of length 1390 chars
# ✔ Done in 1.77s, 1216 chars output.
# [182] id=182 — sending prompt of length 1107 chars
# ✔ Done in 1.54s, 911 chars output.
# [183] id=183 — sending prompt of length 1275 chars
# ✔ Done in 0.78s, 545 chars output.
# [184] id=184 — sending prompt of length 1545 chars
# ✔ Done in 1.14s, 866 chars output.
# [185] id=185 — sending prompt of length 1333 chars
# ✔ Done in 1.83s, 1287 chars output.
# [186] id=186 — sending prompt of length 1324 chars
# ✔ Done in 2.45s, 1563 chars output.
# [187] id=187 — sending prompt of length 1327 chars
# ✔ Done in 1.61s, 1258 chars output.
# [188] id=188 — sending prompt of length 1241 chars
# ✔ Done in 1.66s, 1056 chars output.
# [189] id=189 — sending prompt of length 1318 chars
# ✔ Done in 1.25s, 552 chars output.
# [190] id=190 — sending prompt of length 1443 chars
# ✔ Done in 1.57s, 1286 chars output.
# [191] id=191 — sending prompt of length 1255 chars
# ✔ Done in 0.64s, 343 chars output.
# [192] id=192 — sending prompt of length 1398 chars
# ✔ Done in 1.99s, 1231 chars output.
# [193] id=193 — sending prompt of length 1358 chars
# ✔ Done in 1.04s, 524 chars output.
# [194] id=194 — sending prompt of length 1414 chars
# ✔ Done in 0.52s, 215 chars output.
# [195] id=195 — sending prompt of length 1374 chars
# ✔ Done in 1.58s, 1019 chars output.
# [196] id=196 — sending prompt of length 1339 chars
# ✔ Done in 1.57s, 1175 chars output.
# [197] id=197 — sending prompt of length 1357 chars
# ✔ Done in 1.57s, 1244 chars output.
# [198] id=198 — sending prompt of length 1402 chars
# ✔ Done in 1.58s, 1231 chars output.
# [199] id=199 — sending prompt of length 1274 chars
# ✔ Done in 1.10s, 612 chars output.
# [200] id=200 — sending prompt of length 1413 chars
# ✔ Done in 2.57s, 1242 chars output.
# [201] id=201 — sending prompt of length 1326 chars
# ✔ Done in 1.04s, 689 chars output.
# [202] id=202 — sending prompt of length 1224 chars
# ✔ Done in 1.18s, 1001 chars output.
# [203] id=203 — sending prompt of length 1357 chars
# ✔ Done in 1.64s, 1336 chars output.
# [204] id=204 — sending prompt of length 1357 chars
# ✔ Done in 0.95s, 761 chars output.
# [205] id=205 — sending prompt of length 1357 chars
# ✔ Done in 2.52s, 1305 chars output.
# [206] id=206 — sending prompt of length 1422 chars
# ✔ Done in 1.09s, 699 chars output.
# [207] id=207 — sending prompt of length 1143 chars
# ✔ Done in 0.73s, 375 chars output.
# [208] id=208 — sending prompt of length 1309 chars
# ✔ Done in 0.93s, 547 chars output.
# [209] id=209 — sending prompt of length 1428 chars
# ✔ Done in 0.77s, 510 chars output.
# [210] id=210 — sending prompt of length 1440 chars
# ✔ Done in 1.30s, 1053 chars output.
# [211] id=211 — sending prompt of length 1323 chars
# ✔ Done in 1.29s, 940 chars output.
# [212] id=212 — sending prompt of length 1224 chars
# ✔ Done in 1.23s, 969 chars output.
# [213] id=213 — sending prompt of length 1258 chars
# ✔ Done in 0.57s, 257 chars output.
# [214] id=214 — sending prompt of length 1423 chars
# ✔ Done in 1.59s, 1259 chars output.
# [215] id=215 — sending prompt of length 1319 chars
# ✔ Done in 1.01s, 728 chars output.
# [216] id=216 — sending prompt of length 1425 chars
# ✔ Done in 1.36s, 899 chars output.
# [217] id=217 — sending prompt of length 1495 chars
# ✔ Done in 1.57s, 1295 chars output.
# [218] id=218 — sending prompt of length 1356 chars
# ✔ Done in 1.50s, 1139 chars output.
# [219] id=219 — sending prompt of length 1417 chars
# ✔ Done in 1.51s, 1227 chars output.
# [220] id=220 — sending prompt of length 1175 chars
# ✔ Done in 1.13s, 658 chars output.
# [221] id=221 — sending prompt of length 1288 chars
# ✔ Done in 0.96s, 703 chars output.
# [222] id=222 — sending prompt of length 1365 chars
# ✔ Done in 1.37s, 1045 chars output.
# [223] id=223 — sending prompt of length 1220 chars
# ✔ Done in 0.55s, 219 chars output.
# [224] id=224 — sending prompt of length 1295 chars
# ✔ Done in 0.82s, 525 chars output.
# [225] id=225 — sending prompt of length 1359 chars
# ✔ Done in 1.51s, 1208 chars output.
# [226] id=226 — sending prompt of length 1366 chars
# ✔ Done in 0.80s, 415 chars output.
# [227] id=227 — sending prompt of length 1395 chars
# ✔ Done in 0.71s, 421 chars output.
# [228] id=228 — sending prompt of length 1476 chars
# ✔ Done in 0.94s, 680 chars output.
# [229] id=229 — sending prompt of length 1370 chars
# ✔ Done in 1.24s, 911 chars output.
# [230] id=230 — sending prompt of length 1030 chars
# ✔ Done in 0.63s, 259 chars output.
#
# All queries completed. Results saved to ../results/Mistral-Instruct-7b.jsonl

# %%
# %pip install nltk rouge-score bert-score scikit-learn pandas tqdm
# Out:
# Requirement already satisfied: nltk in /opt/homebrew/lib/python3.11/site-packages (3.6.7)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (1.4.1.post1)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.11/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/homebrew/lib/python3.11/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: absl-py in /opt/homebrew/lib/python3.11/site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /Users/chrisperez/Library/Python/3.11/lib/python/site-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: torch>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from bert-score) (2.2.1)
# Requirement already satisfied: transformers>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from bert-score) (4.46.0)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from bert-score) (2.31.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (from bert-score) (3.7.2)
# Requirement already satisfied: packaging>=20.9 in /Users/chrisperez/Library/Python/3.11/lib/python/site-packages (from bert-score) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chrisperez/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.0.0->bert-score) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.0.0->bert-score) (1.12)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.0.0->bert-score) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.0.0->bert-score) (3.1.2)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.0.0->bert-score) (2023.10.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/homebrew/lib/python3.11/site-packages (from transformers>=3.0.0->bert-score) (0.34.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from transformers>=3.0.0->bert-score) (6.0.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/homebrew/lib/python3.11/site-packages (from transformers>=3.0.0->bert-score) (0.4.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/homebrew/lib/python3.11/site-packages (from transformers>=3.0.0->bert-score) (0.20.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=3.0.0->bert-score) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->bert-score) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->bert-score) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->bert-score) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->bert-score) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->bert-score) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->bert-score) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->bert-score) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests->bert-score) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->bert-score) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
# Building wheels for collected packages: rouge-score
#   DEPRECATION: Building 'rouge-score' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'rouge-score'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=031924243ee1361e333adfc4df860d1446778af6ad62b709085fad93014ef1f7
#   Stored in directory: /Users/chrisperez/Library/Caches/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: rouge-score, bert-score
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [bert-score]
# Successfully installed bert-score-0.3.13 rouge-score-0.1.2
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
def evaluate(results_path: str, out_csv: str = "evaluation_scores.csv"):
    import numpy as np
    import pandas as pd
    from tqdm import tqdm
    from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
    from rouge_score import rouge_scorer
    from sklearn.metrics import f1_score
    from bert_score import score as bert_score

    # Load results (expecting "context" and "output")
    rows = [json.loads(l) for l in open(results_path, "r", encoding="utf-8")]
    # Filter to rows that have both fields (graceful on errors)
    eval_rows = [r for r in rows if isinstance(r.get("context"), str) and isinstance(r.get("output"), str)]

    if not eval_rows:
        print("No rows with both 'context' and 'output' found; skipping evaluation.")
        return

    ids = [r.get("id") for r in eval_rows]
    anchors = [r.get("anchor", "") for r in eval_rows]
    refs = [r["context"] for r in eval_rows]
    hyps = [r["output"]  for r in eval_rows]

    # Metric helpers
    rouge = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)
    smoothie = SmoothingFunction().method1

    def rouge_l(h, r):
        # rouge api expects (target, prediction) order; we compare ref vs hyp
        return rouge.score(r, h)["rougeL"].fmeasure

    def bleu(h, r):
        h_toks = h.split()
        r_toks = [r.split()]
        return sentence_bleu(r_toks, h_toks, smoothing_function=smoothie)

    def token_f1(h, r):
        # multiset-insensitive token presence F1
        h_toks = h.split()
        r_toks = r.split()
        vocab = list(set(h_toks + r_toks))
        h_vec = [1 if t in h_toks else 0 for t in vocab]
        r_vec = [1 if t in r_toks else 0 for t in vocab]
        # Handle degenerate all-zeros gracefully
        try:
            return f1_score(r_vec, h_vec)
        except ValueError:
            return 0.0

    # Compute classical metrics
    rouge_vals, bleu_vals, f1_vals = [], [], []
    for h, r in tqdm(list(zip(hyps, refs)), total=len(hyps), desc="Classical metrics"):
        rouge_vals.append(rouge_l(h, r))
        bleu_vals.append(bleu(h, r))
        f1_vals.append(token_f1(h, r))

    # BERTScore (vectorized). Set device='cuda' if available.
    print("Computing BERTScore...")
    P, R, F = bert_score(hyps, refs, lang="en")
    bert_f1_vals = F.numpy().tolist()

    # 95% CI via normal approx
    def ci95(x):
        x = np.asarray(x, dtype=float)
        mean = x.mean()
        se = x.std(ddof=1) / max(1, np.sqrt(len(x)))
        low, high = mean - 1.96 * se, mean + 1.96 * se
        return mean, low, high

    # Per-row CSV
    df = pd.DataFrame({
        "id": ids,
        "anchor": anchors,
        "ROUGE-L": rouge_vals,
        "BLEU": bleu_vals,
        "Token-F1": f1_vals,
        "BERTScore": bert_f1_vals,
    })
    df.to_csv(out_csv, index=False)
    print(f"Saved detailed scores → {out_csv}")

    # Summary
    r_m, r_l, r_h = ci95(rouge_vals)
    b_m, b_l, b_h = ci95(bleu_vals)
    f_m, f_l, f_h = ci95(f1_vals)
    bs_m, bs_l, bs_h = ci95(bert_f1_vals)

    print("\n=== Mean ± 95% CI ===")
    print(f"ROUGE-L   : {r_m:.4f}  (95% CI {r_l:.4f}–{r_h:.4f})")
    print(f"BLEU      : {b_m:.4f}  (95% CI {b_l:.4f}–{b_h:.4f})")
    print(f"Token-F1  : {f_m:.4f}  (95% CI {f_l:.4f}–{f_h:.4f})")
    print(f"BERTScore : {bs_m:.4f} (95% CI {bs_l:.4f}–{bs_h:.4f})")

# %%
csv_eval_path = os.path.splitext(OUTPUT_FILE)[0] + ".csv"
evaluate(OUTPUT_FILE, out_csv=csv_eval_path)
# Out:
# Classical metrics: 100%|██████████| 230/230 [00:01<00:00, 147.70it/s]
# Computing BERTScore...
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:801: UserWarning: Not enough free disk space to download the file. The expected file size is: 1421.70 MB. The target location /Users/chrisperez/.cache/huggingface/hub/models--roberta-large/blobs only has 698.58 MB free disk space.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:629, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     627     progress.update(progress_bytes)
# --> 629 download_files(
#     630     xet_download_info,
#     631     endpoint=connection_info.endpoint,
#     632     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     633     token_refresher=token_refresher,
#     634     progress_updater=[progress_updater],
#     635 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 csv_eval_path = os.path.splitext(OUTPUT_FILE)[0] + ".csv"
# ----> 2 evaluate(OUTPUT_FILE, out_csv=csv_eval_path)
#
# Cell In[35], line 59, in evaluate(results_path, out_csv)
#      57 # BERTScore (vectorized). Set device='cuda' if available.
#      58 print("Computing BERTScore...")
# ---> 59 P, R, F = bert_score(hyps, refs, lang="en")
#      60 bert_f1_vals = F.numpy().tolist()
#      62 # 95% CI via normal approx
#
# File /opt/homebrew/lib/python3.11/site-packages/bert_score/score.py:98, in score(cands, refs, model_type, num_layers, verbose, idf, device, batch_size, nthreads, all_layers, lang, return_hash, rescale_with_baseline, baseline_path, use_fast_tokenizer)
#      95     num_layers = model2layers[model_type]
#      97 tokenizer = get_tokenizer(model_type, use_fast_tokenizer)
# ---> 98 model = get_model(model_type, num_layers, all_layers)
#      99 if device is None:
#     100     device = "cuda" if torch.cuda.is_available() else "cpu"
#
# File /opt/homebrew/lib/python3.11/site-packages/bert_score/utils.py:255, in get_model(model_type, num_layers, all_layers)
#     253     model = T5EncoderModel.from_pretrained(model_type)
#     254 else:
# --> 255     model = AutoModel.from_pretrained(model_type)
#     256 model.eval()
#     258 if hasattr(model, "decoder") and hasattr(model, "encoder"):
#
# File /opt/homebrew/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File /opt/homebrew/lib/python3.11/site-packages/transformers/modeling_utils.py:3808, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3792 try:
#    3793     # Load from URL or cache if already cached
#    3794     cached_file_kwargs = {
#    3795         "cache_dir": cache_dir,
#    3796         "force_download": force_download,
#    (...)
#    3806         "_commit_hash": commit_hash,
#    3807     }
# -> 3808     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    3810     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    3811     # result when internet is up, the repo and revision exist, but the file does not.
#    3812     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    3813         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File /opt/homebrew/lib/python3.11/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#    (...)
#    1007         local_files_only=local_files_only,
#    1008     )
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:1171, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1168 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1170 with WeakFileLock(lock_path):
# -> 1171     _download_to_tmp_and_move(
#    1172         incomplete_path=Path(blob_path + ".incomplete"),
#    1173         destination_path=Path(blob_path),
#    1174         url_to_download=url_to_download,
#    1175         proxies=proxies,
#    1176         headers=headers,
#    1177         expected_size=expected_size,
#    1178         filename=filename,
#    1179         force_download=force_download,
#    1180         etag=etag,
#    1181         xet_file_data=xet_file_data,
#    1182     )
#    1183     if not os.path.exists(pointer_path):
#    1184         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:1723, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1721 if xet_file_data is not None and is_xet_available():
#    1722     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1723     xet_get(
#    1724         incomplete_path=incomplete_path,
#    1725         xet_file_data=xet_file_data,
#    1726         headers=headers,
#    1727         expected_size=expected_size,
#    1728         displayed_filename=filename,
#    1729     )
#    1730 else:
#    1731     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File /opt/homebrew/lib/python3.11/site-packages/huggingface_hub/file_download.py:624, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, _tqdm_bar)
#     613     displayed_filename = f"{displayed_filename[:40]}(…)"
#     615 progress_cm = _get_progress_bar_context(
#     616     desc=displayed_filename,
#     617     log_level=logger.getEffectiveLevel(),
#    (...)
#     621     _tqdm_bar=_tqdm_bar,
#     622 )
# --> 624 with progress_cm as progress:
#     626     def progress_updater(progress_bytes: float):
#     627         progress.update(progress_bytes)
#
# File /opt/homebrew/lib/python3.11/site-packages/tqdm/std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:
