# %%
# %pip install transformers accelerate torch sentencepiece bitsandbytes aiohttp requests --quiet together

# %%
from dotenv import load_dotenv
import os, json, time
from together import Together

load_dotenv()
api_key = 

client = Together(api_key=api_key)

MODEL = "chrisperez04_345b/meta-llama/Llama-2-7b-chat-hf-ce20084e"

INPUT_FILE = "/content/data/query_data.jsonl"
OUTPUT_FILE = "/content/results/Llama-2-7b-chat-hf.jsonl"

# %%
GEN_CFG = dict(
    max_tokens=512,
    temperature=0.2,
    top_p=0.9,
    top_k=60,
    num_beams=1,
    repetition_penalty=1.0,
    stop=["</s>"],
)

# %%
def run_query(prompt: str):
    """
    Send one prompt to the model (chat or completions endpoint) and
    return (text, latency).  Works for Together dedicated endpoints.
    """
    import time
    start = time.time()

    # --- First try chat.completions (some endpoints accept this) ---
    try:
        resp = client.chat.completions.create(
            model=MODEL,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=512,
            temperature=0.2,
            top_p=0.9,
            stop=["</s>"],         # keep minimal safe args
        )
        text = resp.choices[0].message.content if resp.choices else ""
        return text.strip(), time.time() - start
    except Exception as e1:
        err1 = str(e1)

    # --- Fallback: completions endpoint with Llama-2 chat template ---
    sys_prompt = "You are a helpful assistant."
    templated = f"<<SYS>>\n{sys_prompt}\n<</SYS>>\n\n[INST] {prompt} [/INST]"

    try:
        resp = client.completions.create(
            model=MODEL,
            prompt=templated,
            max_tokens=512,
            temperature=0.2,
            top_p=0.9,
            stop=["</s>"],
        )
        text = resp.choices[0].text if resp.choices else ""
        return text.strip(), time.time() - start
    except Exception as e2:
        # If both fail, show both errors for debugging
        raise RuntimeError(
            f"chat.completions and completions both failed.\n"
            f"chat error: {err1}\n"
            f"completions error: {e2}"
        )

# %%
with open(INPUT_FILE, "r", encoding="utf-8") as fin, \
        open(OUTPUT_FILE, "w", encoding="utf-8") as fout:

    for i, line in enumerate(fin, 1):
        row = json.loads(line)

        context = row.get("context", "")
        prompt = row.get("prompt", "")
        anchor = row.get("anchor", "")
        qid = row.get("id", i)


        print(f"[{i}] id={qid} — sending prompt of length {len(prompt)} chars")

        try:
            output, latency = run_query(prompt)
            result = {
                "id": qid,
                "context": context,
                "prompt": prompt,
                "anchor": anchor,
                "output": output,
                "latency_sec": round(latency, 3),
                "model": MODEL,
            }
            fout.write(json.dumps(result, ensure_ascii=False) + "\n")
            print(f"✔ Done in {latency:.2f}s, {len(output)} chars output.")
        except Exception as e:
            print(f"✖ Error on example {i}: {e}")
            fout.write(json.dumps({
                "id": qid,
                "context": context,
                "prompt": prompt,
                "anchor": anchor,
                "error": str(e),
                "model": MODEL,
            }, ensure_ascii=False) + "\n")

print(f"\nAll queries completed. Results saved to {OUTPUT_FILE}")
# Out:
# [1] id=1 — sending prompt of length 1137 chars
# ✔ Done in 3.20s, 511 chars output.
# [2] id=2 — sending prompt of length 1695 chars
# ✔ Done in 2.08s, 1234 chars output.
# [3] id=3 — sending prompt of length 1335 chars
# ✔ Done in 2.40s, 1188 chars output.
# [4] id=4 — sending prompt of length 1491 chars
# ✔ Done in 1.97s, 953 chars output.
# [5] id=5 — sending prompt of length 1546 chars
# ✔ Done in 2.09s, 1214 chars output.
# [6] id=6 — sending prompt of length 1514 chars
# ✔ Done in 2.32s, 1523 chars output.
# [7] id=7 — sending prompt of length 1411 chars
# ✔ Done in 1.57s, 473 chars output.
# [8] id=8 — sending prompt of length 1349 chars
# ✔ Done in 2.21s, 1094 chars output.
# [9] id=9 — sending prompt of length 1356 chars
# ✔ Done in 1.56s, 979 chars output.
# [10] id=10 — sending prompt of length 1468 chars
# ✔ Done in 1.97s, 835 chars output.
# [11] id=11 — sending prompt of length 1279 chars
# ✔ Done in 1.50s, 417 chars output.
# [12] id=12 — sending prompt of length 1218 chars
# ✔ Done in 1.85s, 1200 chars output.
# [13] id=13 — sending prompt of length 1416 chars
# ✔ Done in 2.21s, 1268 chars output.
# [14] id=14 — sending prompt of length 1259 chars
# ✔ Done in 2.24s, 1115 chars output.
# [15] id=15 — sending prompt of length 1321 chars
# ✔ Done in 1.92s, 889 chars output.
# [16] id=16 — sending prompt of length 1570 chars
# ✔ Done in 1.40s, 905 chars output.
# [17] id=17 — sending prompt of length 1391 chars
# ✔ Done in 1.96s, 436 chars output.
# [18] id=18 — sending prompt of length 1378 chars
# ✔ Done in 1.85s, 1273 chars output.
# [19] id=19 — sending prompt of length 1389 chars
# ✔ Done in 1.92s, 838 chars output.
# [20] id=20 — sending prompt of length 1279 chars
# ✔ Done in 1.67s, 1069 chars output.
# [21] id=21 — sending prompt of length 1365 chars
# ✔ Done in 2.06s, 1258 chars output.
# [22] id=22 — sending prompt of length 1445 chars
# ✔ Done in 1.81s, 1305 chars output.
# [23] id=23 — sending prompt of length 1322 chars
# ✔ Done in 1.87s, 1165 chars output.
# [24] id=24 — sending prompt of length 1394 chars
# ✔ Done in 2.11s, 1260 chars output.
# [25] id=25 — sending prompt of length 1264 chars
# ✔ Done in 2.16s, 1113 chars output.
# [26] id=26 — sending prompt of length 1353 chars
# ✔ Done in 1.73s, 1229 chars output.
# [27] id=27 — sending prompt of length 1388 chars
# ✔ Done in 1.65s, 1126 chars output.
# [28] id=28 — sending prompt of length 1064 chars
# ✔ Done in 1.95s, 962 chars output.
# [29] id=29 — sending prompt of length 1280 chars
# ✔ Done in 1.44s, 387 chars output.
# [30] id=30 — sending prompt of length 1282 chars
# ✔ Done in 1.87s, 1194 chars output.
# [31] id=31 — sending prompt of length 1511 chars
# ✔ Done in 1.72s, 1278 chars output.
# [32] id=32 — sending prompt of length 1435 chars
# ✔ Done in 2.40s, 1410 chars output.
# [33] id=33 — sending prompt of length 1188 chars
# ✔ Done in 1.02s, 327 chars output.
# [34] id=34 — sending prompt of length 1389 chars
# ✔ Done in 1.32s, 707 chars output.
# [35] id=35 — sending prompt of length 1443 chars
# ✔ Done in 1.86s, 1348 chars output.
# [36] id=36 — sending prompt of length 1244 chars
# ✔ Done in 1.96s, 1115 chars output.
# [37] id=37 — sending prompt of length 1321 chars
# ✔ Done in 1.85s, 1195 chars output.
# [38] id=38 — sending prompt of length 1422 chars
# ✔ Done in 1.85s, 1298 chars output.
# [39] id=39 — sending prompt of length 1366 chars
# ✔ Done in 1.65s, 1099 chars output.
# [40] id=40 — sending prompt of length 1305 chars
# ✔ Done in 1.55s, 903 chars output.
# [41] id=41 — sending prompt of length 1313 chars
# ✔ Done in 1.95s, 1243 chars output.
# [42] id=42 — sending prompt of length 1223 chars
# ✔ Done in 1.78s, 1045 chars output.
# [43] id=43 — sending prompt of length 1244 chars
# ✔ Done in 2.16s, 1210 chars output.
# [44] id=44 — sending prompt of length 1376 chars
# ✔ Done in 1.84s, 1288 chars output.
# [45] id=45 — sending prompt of length 1223 chars
# ✔ Done in 2.26s, 1071 chars output.
# [46] id=46 — sending prompt of length 1227 chars
# ✔ Done in 2.24s, 1098 chars output.
# [47] id=47 — sending prompt of length 1378 chars
# ✔ Done in 2.22s, 1265 chars output.
# [48] id=48 — sending prompt of length 1206 chars
# ✔ Done in 1.55s, 782 chars output.
# [49] id=49 — sending prompt of length 1457 chars
# ✔ Done in 1.74s, 1311 chars output.
# [50] id=50 — sending prompt of length 1444 chars
# ✔ Done in 1.69s, 1179 chars output.
# [51] id=51 — sending prompt of length 1350 chars
# ✔ Done in 1.57s, 1063 chars output.
# [52] id=52 — sending prompt of length 1145 chars
# ✔ Done in 1.89s, 672 chars output.
# [53] id=53 — sending prompt of length 1208 chars
# ✔ Done in 1.02s, 337 chars output.
# [54] id=54 — sending prompt of length 875 chars
# ✔ Done in 1.66s, 758 chars output.
# [55] id=55 — sending prompt of length 1420 chars
# ✔ Done in 1.65s, 1094 chars output.
# [56] id=56 — sending prompt of length 1346 chars
# ✔ Done in 1.37s, 274 chars output.
# [57] id=57 — sending prompt of length 1329 chars
# ✔ Done in 1.95s, 1214 chars output.
# [58] id=58 — sending prompt of length 1402 chars
# ✔ Done in 1.12s, 636 chars output.
# [59] id=59 — sending prompt of length 1407 chars
# ✔ Done in 1.80s, 1317 chars output.
# [60] id=60 — sending prompt of length 1352 chars
# ✔ Done in 1.68s, 918 chars output.
# [61] id=61 — sending prompt of length 1389 chars
# ✔ Done in 1.67s, 672 chars output.
# [62] id=62 — sending prompt of length 1330 chars
# ✔ Done in 1.20s, 560 chars output.
# [63] id=63 — sending prompt of length 1439 chars
# ✔ Done in 1.73s, 1243 chars output.
# [64] id=64 — sending prompt of length 1417 chars
# ✔ Done in 1.68s, 1076 chars output.
# [65] id=65 — sending prompt of length 1301 chars
# ✔ Done in 1.06s, 409 chars output.
# [66] id=66 — sending prompt of length 1293 chars
# ✔ Done in 1.71s, 1122 chars output.
# [67] id=67 — sending prompt of length 1411 chars
# ✔ Done in 1.32s, 765 chars output.
# [68] id=68 — sending prompt of length 1126 chars
# ✔ Done in 1.70s, 993 chars output.
# [69] id=69 — sending prompt of length 1354 chars
# ✔ Done in 1.41s, 748 chars output.
# [70] id=70 — sending prompt of length 1215 chars
# ✔ Done in 1.67s, 1040 chars output.
# [71] id=71 — sending prompt of length 1486 chars
# ✔ Done in 1.63s, 1169 chars output.
# [72] id=72 — sending prompt of length 920 chars
# ✔ Done in 1.34s, 776 chars output.
# [73] id=73 — sending prompt of length 1526 chars
# ✔ Done in 2.23s, 1269 chars output.
# [74] id=74 — sending prompt of length 1209 chars
# ✔ Done in 1.84s, 1040 chars output.
# [75] id=75 — sending prompt of length 1369 chars
# ✔ Done in 1.72s, 1271 chars output.
# [76] id=76 — sending prompt of length 1344 chars
# ✔ Done in 1.91s, 1326 chars output.
# [77] id=77 — sending prompt of length 1374 chars
# ✔ Done in 1.79s, 1282 chars output.
# [78] id=78 — sending prompt of length 1081 chars
# ✔ Done in 1.36s, 774 chars output.
# [79] id=79 — sending prompt of length 1403 chars
# ✔ Done in 1.90s, 1324 chars output.
# [80] id=80 — sending prompt of length 1287 chars
# ✔ Done in 1.58s, 816 chars output.
# [81] id=81 — sending prompt of length 1192 chars
# ✔ Done in 1.27s, 500 chars output.
# [82] id=82 — sending prompt of length 1464 chars
# ✔ Done in 1.84s, 1329 chars output.
# [83] id=83 — sending prompt of length 1368 chars
# ✔ Done in 1.46s, 957 chars output.
# [84] id=84 — sending prompt of length 1504 chars
# ✔ Done in 1.43s, 937 chars output.
# [85] id=85 — sending prompt of length 1250 chars
# ✔ Done in 1.53s, 870 chars output.
# [86] id=86 — sending prompt of length 1454 chars
# ✔ Done in 1.78s, 1144 chars output.
# [87] id=87 — sending prompt of length 1191 chars
# ✔ Done in 2.32s, 1069 chars output.
# [88] id=88 — sending prompt of length 1273 chars
# ✔ Done in 1.29s, 669 chars output.
# [89] id=89 — sending prompt of length 887 chars
# ✔ Done in 1.13s, 477 chars output.
# [90] id=90 — sending prompt of length 1321 chars
# ✔ Done in 1.66s, 1080 chars output.
# [91] id=91 — sending prompt of length 1281 chars
# ✔ Done in 1.71s, 1138 chars output.
# [92] id=92 — sending prompt of length 1475 chars
# ✔ Done in 2.86s, 1393 chars output.
# [93] id=93 — sending prompt of length 1284 chars
# ✔ Done in 1.85s, 1184 chars output.
# [94] id=94 — sending prompt of length 1240 chars
# ✔ Done in 1.29s, 665 chars output.
# [95] id=95 — sending prompt of length 1436 chars
# ✔ Done in 1.65s, 1078 chars output.
# [96] id=96 — sending prompt of length 1251 chars
# ✔ Done in 1.49s, 748 chars output.
# [97] id=97 — sending prompt of length 1335 chars
# ✔ Done in 1.90s, 1217 chars output.
# [98] id=98 — sending prompt of length 1399 chars
# ✔ Done in 2.08s, 1679 chars output.
# [99] id=99 — sending prompt of length 1411 chars
# ✔ Done in 1.31s, 798 chars output.
# [100] id=100 — sending prompt of length 1213 chars
# ✔ Done in 1.80s, 1134 chars output.
# [101] id=101 — sending prompt of length 1239 chars
# ✔ Done in 1.64s, 1058 chars output.
# [102] id=102 — sending prompt of length 1152 chars
# ✔ Done in 1.36s, 590 chars output.
# [103] id=103 — sending prompt of length 1441 chars
# ✔ Done in 1.59s, 1307 chars output.
# [104] id=104 — sending prompt of length 1204 chars
# ✔ Done in 1.79s, 1076 chars output.
# [105] id=105 — sending prompt of length 1378 chars
# ✔ Done in 1.65s, 1109 chars output.
# [106] id=106 — sending prompt of length 1249 chars
# ✔ Done in 1.74s, 1084 chars output.
# [107] id=107 — sending prompt of length 1330 chars
# ✔ Done in 1.08s, 496 chars output.
# [108] id=108 — sending prompt of length 1310 chars
# ✔ Done in 1.29s, 693 chars output.
# [109] id=109 — sending prompt of length 1231 chars
# ✔ Done in 1.75s, 1128 chars output.
# [110] id=110 — sending prompt of length 1332 chars
# ✔ Done in 1.53s, 891 chars output.
# [111] id=111 — sending prompt of length 1521 chars
# ✔ Done in 1.75s, 1269 chars output.
# [112] id=112 — sending prompt of length 1388 chars
# ✔ Done in 1.43s, 954 chars output.
# [113] id=113 — sending prompt of length 1416 chars
# ✔ Done in 2.15s, 1179 chars output.
# [114] id=114 — sending prompt of length 1488 chars
# ✔ Done in 1.94s, 1415 chars output.
# [115] id=115 — sending prompt of length 1238 chars
# ✔ Done in 1.72s, 1058 chars output.
# [116] id=116 — sending prompt of length 1364 chars
# ✔ Done in 1.71s, 1266 chars output.
# [117] id=117 — sending prompt of length 1459 chars
# ✔ Done in 1.04s, 503 chars output.
# [118] id=118 — sending prompt of length 1407 chars
# ✔ Done in 1.58s, 817 chars output.
# [119] id=119 — sending prompt of length 1267 chars
# ✔ Done in 1.84s, 1160 chars output.
# [120] id=120 — sending prompt of length 1140 chars
# ✔ Done in 2.16s, 913 chars output.
# [121] id=121 — sending prompt of length 1456 chars
# ✔ Done in 1.97s, 1629 chars output.
# [122] id=122 — sending prompt of length 1406 chars
# ✔ Done in 1.79s, 1262 chars output.
# [123] id=123 — sending prompt of length 1267 chars
# ✔ Done in 1.74s, 1115 chars output.
# [124] id=124 — sending prompt of length 1532 chars
# ✔ Done in 1.63s, 1035 chars output.
# [125] id=125 — sending prompt of length 1274 chars
# ✔ Done in 1.41s, 275 chars output.
# [126] id=126 — sending prompt of length 1500 chars
# ✔ Done in 1.12s, 552 chars output.
# [127] id=127 — sending prompt of length 1366 chars
# ✔ Done in 2.06s, 1359 chars output.
# [128] id=128 — sending prompt of length 1253 chars
# ✔ Done in 1.78s, 991 chars output.
# [129] id=129 — sending prompt of length 1363 chars
# ✔ Done in 2.39s, 2301 chars output.
# [130] id=130 — sending prompt of length 1472 chars
# ✔ Done in 1.85s, 1382 chars output.
# [131] id=131 — sending prompt of length 1293 chars
# ✔ Done in 1.66s, 1163 chars output.
# [132] id=132 — sending prompt of length 1230 chars
# ✔ Done in 1.72s, 1115 chars output.
# [133] id=133 — sending prompt of length 1217 chars
# ✔ Done in 1.55s, 922 chars output.
# [134] id=134 — sending prompt of length 1403 chars
# ✔ Done in 1.97s, 1247 chars output.
# [135] id=135 — sending prompt of length 1335 chars
# ✔ Done in 1.56s, 980 chars output.
# [136] id=136 — sending prompt of length 1209 chars
# ✔ Done in 1.30s, 626 chars output.
# [137] id=137 — sending prompt of length 1200 chars
# ✔ Done in 1.84s, 1231 chars output.
# [138] id=138 — sending prompt of length 1322 chars
# ✔ Done in 1.75s, 1219 chars output.
# [139] id=139 — sending prompt of length 1417 chars
# ✔ Done in 1.91s, 1398 chars output.
# [140] id=140 — sending prompt of length 1228 chars
# ✔ Done in 1.93s, 1115 chars output.
# [141] id=141 — sending prompt of length 1411 chars
# ✔ Done in 1.82s, 1274 chars output.
# [142] id=142 — sending prompt of length 1497 chars
# ✔ Done in 1.03s, 410 chars output.
# [143] id=143 — sending prompt of length 1293 chars
# ✔ Done in 1.55s, 965 chars output.
# [144] id=144 — sending prompt of length 1562 chars
# ✔ Done in 1.73s, 1316 chars output.
# [145] id=145 — sending prompt of length 1308 chars
# ✔ Done in 1.85s, 1214 chars output.
# [146] id=146 — sending prompt of length 1400 chars
# ✔ Done in 1.61s, 1088 chars output.
# [147] id=147 — sending prompt of length 1554 chars
# ✔ Done in 1.61s, 1179 chars output.
# [148] id=148 — sending prompt of length 1401 chars
# ✔ Done in 1.92s, 1336 chars output.
# [149] id=149 — sending prompt of length 1367 chars
# ✔ Done in 1.86s, 1299 chars output.
# [150] id=150 — sending prompt of length 1355 chars
# ✔ Done in 1.26s, 643 chars output.
# [151] id=151 — sending prompt of length 1297 chars
# ✔ Done in 1.21s, 637 chars output.
# [152] id=152 — sending prompt of length 1444 chars
# ✔ Done in 1.76s, 1346 chars output.
# [153] id=153 — sending prompt of length 1208 chars
# ✔ Done in 1.39s, 644 chars output.
# [154] id=154 — sending prompt of length 1392 chars
# ✔ Done in 2.01s, 1503 chars output.
# [155] id=155 — sending prompt of length 1236 chars
# ✔ Done in 1.77s, 1180 chars output.
# [156] id=156 — sending prompt of length 1323 chars
# ✔ Done in 1.77s, 1286 chars output.
# [157] id=157 — sending prompt of length 1440 chars
# ✔ Done in 1.58s, 1159 chars output.
# [158] id=158 — sending prompt of length 1399 chars
# ✔ Done in 1.75s, 1072 chars output.
# [159] id=159 — sending prompt of length 1397 chars
# ✔ Done in 1.29s, 758 chars output.
# [160] id=160 — sending prompt of length 1396 chars
# ✔ Done in 1.68s, 1206 chars output.
# [161] id=161 — sending prompt of length 1360 chars
# ✔ Done in 2.46s, 1967 chars output.
# [162] id=162 — sending prompt of length 963 chars
# ✔ Done in 1.97s, 559 chars output.
# [163] id=163 — sending prompt of length 1238 chars
# ✔ Done in 0.89s, 227 chars output.
# [164] id=164 — sending prompt of length 1286 chars
# ✔ Done in 1.26s, 488 chars output.
# [165] id=165 — sending prompt of length 1318 chars
# ✔ Done in 1.37s, 756 chars output.
# [166] id=166 — sending prompt of length 1262 chars
# ✔ Done in 1.72s, 1107 chars output.
# [167] id=167 — sending prompt of length 1480 chars
# ✔ Done in 1.94s, 1487 chars output.
# [168] id=168 — sending prompt of length 1444 chars
# ✔ Done in 1.81s, 1336 chars output.
# [169] id=169 — sending prompt of length 1394 chars
# ✔ Done in 1.03s, 482 chars output.
# [170] id=170 — sending prompt of length 1352 chars
# ✔ Done in 1.25s, 708 chars output.
# [171] id=171 — sending prompt of length 1484 chars
# ✔ Done in 1.43s, 995 chars output.
# [172] id=172 — sending prompt of length 1458 chars
# ✔ Done in 1.88s, 1288 chars output.
# [173] id=173 — sending prompt of length 1500 chars
# ✔ Done in 1.13s, 574 chars output.
# [174] id=174 — sending prompt of length 1453 chars
# ✔ Done in 1.90s, 1331 chars output.
# [175] id=175 — sending prompt of length 1505 chars
# ✔ Done in 1.06s, 477 chars output.
# [176] id=176 — sending prompt of length 1298 chars
# ✔ Done in 1.79s, 1191 chars output.
# [177] id=177 — sending prompt of length 1326 chars
# ✔ Done in 1.86s, 1374 chars output.
# [178] id=178 — sending prompt of length 1233 chars
# ✔ Done in 1.68s, 1058 chars output.
# [179] id=179 — sending prompt of length 1235 chars
# ✔ Done in 2.01s, 1468 chars output.
# [180] id=180 — sending prompt of length 1255 chars
# ✔ Done in 1.66s, 1035 chars output.
# [181] id=181 — sending prompt of length 1390 chars
# ✔ Done in 1.89s, 1275 chars output.
# [182] id=182 — sending prompt of length 1107 chars
# ✔ Done in 1.55s, 822 chars output.
# [183] id=183 — sending prompt of length 1275 chars
# ✔ Done in 1.81s, 1213 chars output.
# [184] id=184 — sending prompt of length 1545 chars
# ✔ Done in 2.04s, 1421 chars output.
# [185] id=185 — sending prompt of length 1333 chars
# ✔ Done in 0.95s, 297 chars output.
# [186] id=186 — sending prompt of length 1324 chars
# ✔ Done in 1.53s, 968 chars output.
# [187] id=187 — sending prompt of length 1327 chars
# ✔ Done in 1.66s, 1158 chars output.
# [188] id=188 — sending prompt of length 1241 chars
# ✔ Done in 2.51s, 1893 chars output.
# [189] id=189 — sending prompt of length 1318 chars
# ✔ Done in 1.28s, 576 chars output.
# [190] id=190 — sending prompt of length 1443 chars
# ✔ Done in 1.16s, 639 chars output.
# [191] id=191 — sending prompt of length 1255 chars
# ✔ Done in 1.33s, 601 chars output.
# [192] id=192 — sending prompt of length 1398 chars
# ✔ Done in 1.59s, 1003 chars output.
# [193] id=193 — sending prompt of length 1358 chars
# ✔ Done in 1.91s, 1173 chars output.
# [194] id=194 — sending prompt of length 1414 chars
# ✔ Done in 1.73s, 1325 chars output.
# [195] id=195 — sending prompt of length 1374 chars
# ✔ Done in 1.55s, 979 chars output.
# [196] id=196 — sending prompt of length 1339 chars
# ✔ Done in 1.72s, 1197 chars output.
# [197] id=197 — sending prompt of length 1357 chars
# ✔ Done in 1.47s, 1018 chars output.
# [198] id=198 — sending prompt of length 1402 chars
# ✔ Done in 1.79s, 1293 chars output.
# [199] id=199 — sending prompt of length 1274 chars
# ✔ Done in 1.48s, 737 chars output.
# [200] id=200 — sending prompt of length 1413 chars
# ✔ Done in 1.99s, 1473 chars output.
# [201] id=201 — sending prompt of length 1326 chars
# ✔ Done in 1.64s, 1116 chars output.
# [202] id=202 — sending prompt of length 1224 chars
# ✔ Done in 1.61s, 1150 chars output.
# [203] id=203 — sending prompt of length 1357 chars
# ✔ Done in 1.40s, 974 chars output.
# [204] id=204 — sending prompt of length 1357 chars
# ✔ Done in 1.54s, 904 chars output.
# [205] id=205 — sending prompt of length 1357 chars
# ✔ Done in 1.49s, 1027 chars output.
# [206] id=206 — sending prompt of length 1422 chars
# ✔ Done in 1.90s, 1343 chars output.
# [207] id=207 — sending prompt of length 1143 chars
# ✔ Done in 1.71s, 964 chars output.
# [208] id=208 — sending prompt of length 1309 chars
# ✔ Done in 1.73s, 1112 chars output.
# [209] id=209 — sending prompt of length 1428 chars
# ✔ Done in 1.90s, 1308 chars output.
# [210] id=210 — sending prompt of length 1440 chars
# ✔ Done in 1.80s, 1341 chars output.
# [211] id=211 — sending prompt of length 1323 chars
# ✔ Done in 1.92s, 1425 chars output.
# [212] id=212 — sending prompt of length 1224 chars
# ✔ Done in 1.74s, 1244 chars output.
# [213] id=213 — sending prompt of length 1258 chars
# ✔ Done in 1.85s, 1195 chars output.
# [214] id=214 — sending prompt of length 1423 chars
# ✔ Done in 1.84s, 1318 chars output.
# [215] id=215 — sending prompt of length 1319 chars
# ✔ Done in 2.09s, 1105 chars output.
# [216] id=216 — sending prompt of length 1425 chars
# ✔ Done in 1.72s, 1102 chars output.
# [217] id=217 — sending prompt of length 1495 chars
# ✔ Done in 1.83s, 1433 chars output.
# [218] id=218 — sending prompt of length 1356 chars
# ✔ Done in 1.60s, 1110 chars output.
# [219] id=219 — sending prompt of length 1417 chars
# ✔ Done in 1.72s, 1245 chars output.
# [220] id=220 — sending prompt of length 1175 chars
# ✔ Done in 2.11s, 1215 chars output.
# [221] id=221 — sending prompt of length 1288 chars
# ✔ Done in 1.82s, 1318 chars output.
# [222] id=222 — sending prompt of length 1365 chars
# ✔ Done in 1.77s, 1164 chars output.
# [223] id=223 — sending prompt of length 1220 chars
# ✔ Done in 1.91s, 736 chars output.
# [224] id=224 — sending prompt of length 1295 chars
# ✔ Done in 1.73s, 1145 chars output.
# [225] id=225 — sending prompt of length 1359 chars
# ✔ Done in 1.73s, 1207 chars output.
# [226] id=226 — sending prompt of length 1366 chars
# ✔ Done in 1.11s, 496 chars output.
# [227] id=227 — sending prompt of length 1395 chars
# ✔ Done in 1.93s, 1288 chars output.
# [228] id=228 — sending prompt of length 1476 chars
# ✔ Done in 2.00s, 480 chars output.
# [229] id=229 — sending prompt of length 1370 chars
# ✔ Done in 1.04s, 452 chars output.
# [230] id=230 — sending prompt of length 1030 chars
# ✔ Done in 1.77s, 853 chars output.
#
# All queries completed. Results saved to /content/results/Llama-2-7b-chat-hf.jsonl

# %%
# %pip install nltk rouge-score bert-score scikit-learn pandas tqdm
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.57.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2025.10.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert-score) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.3)

# %%
# %pip install nltk rouge-score bert-score scikit-learn pandas tqdm
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: bert-score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.57.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2025.10.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert-score) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.3)

# %%
def evaluate(results_path: str, out_csv: str = "evaluation_scores.csv"):
    import numpy as np
    import pandas as pd
    from tqdm import tqdm
    from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
    from rouge_score import rouge_scorer
    from sklearn.metrics import f1_score
    from bert_score import score as bert_score

    # Load results (expecting "context" and "output")
    rows = []
    with open(results_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue  # skip blank lines
            try:
                rows.append(json.loads(line))
            except json.JSONDecodeError:
                print(f"⚠️ Skipping malformed line: {line[:60]}...")
                continue
    # Filter to rows that have both fields (graceful on errors)
    eval_rows = [r for r in rows if isinstance(r.get("context"), str) and isinstance(r.get("output"), str)]

    if not eval_rows:
        print("No rows with both 'context' and 'output' found; skipping evaluation.")
        return

    ids = [r.get("id") for r in eval_rows]
    anchors = [r.get("anchor", "") for r in eval_rows]
    refs = [r["context"] for r in eval_rows]
    hyps = [r["output"]  for r in eval_rows]

    # Metric helpers
    rouge = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)
    smoothie = SmoothingFunction().method1

    def rouge_l(h, r):
        # rouge api expects (target, prediction) order; we compare ref vs hyp
        return rouge.score(r, h)["rougeL"].fmeasure

    def bleu(h, r):
        h_toks = h.split()
        r_toks = [r.split()]
        return sentence_bleu(r_toks, h_toks, smoothing_function=smoothie)

    def token_f1(h, r):
        # multiset-insensitive token presence F1
        h_toks = h.split()
        r_toks = r.split()
        vocab = list(set(h_toks + r_toks))
        h_vec = [1 if t in h_toks else 0 for t in vocab]
        r_vec = [1 if t in r_toks else 0 for t in vocab]
        # Handle degenerate all-zeros gracefully
        try:
            return f1_score(r_vec, h_vec)
        except ValueError:
            return 0.0

    # Compute classical metrics
    rouge_vals, bleu_vals, f1_vals = [], [], []
    for h, r in tqdm(list(zip(hyps, refs)), total=len(hyps), desc="Classical metrics"):
        rouge_vals.append(rouge_l(h, r))
        bleu_vals.append(bleu(h, r))
        f1_vals.append(token_f1(h, r))

    # BERTScore (vectorized). Set device='cuda' if available.
    print("Computing BERTScore...")
    P, R, F = bert_score(hyps, refs, lang="en")
    bert_f1_vals = F.numpy().tolist()

    # 95% CI via normal approx
    def ci95(x):
        x = np.asarray(x, dtype=float)
        mean = x.mean()
        se = x.std(ddof=1) / max(1, np.sqrt(len(x)))
        low, high = mean - 1.96 * se, mean + 1.96 * se
        return mean, low, high

    # Per-row CSV
    df = pd.DataFrame({
        "id": ids,
        "anchor": anchors,
        "ROUGE-L": rouge_vals,
        "BLEU": bleu_vals,
        "Token-F1": f1_vals,
        "BERTScore": bert_f1_vals,
    })
    df.to_csv(out_csv, index=False)
    print(f"Saved detailed scores → {out_csv}")

    # Summary
    r_m, r_l, r_h = ci95(rouge_vals)
    b_m, b_l, b_h = ci95(bleu_vals)
    f_m, f_l, f_h = ci95(f1_vals)
    bs_m, bs_l, bs_h = ci95(bert_f1_vals)

    print("\n=== Mean ± 95% CI ===")
    print(f"ROUGE-L   : {r_m:.4f}  (95% CI {r_l:.4f}–{r_h:.4f})")
    print(f"BLEU      : {b_m:.4f}  (95% CI {b_l:.4f}–{b_h:.4f})")
    print(f"Token-F1  : {f_m:.4f}  (95% CI {f_l:.4f}–{f_h:.4f})")
    print(f"BERTScore : {bs_m:.4f} (95% CI {bs_l:.4f}–{bs_h:.4f})")

# %%
csv_eval_path = os.path.splitext(OUTPUT_FILE)[0] + ".csv"
evaluate(OUTPUT_FILE, out_csv=csv_eval_path)
# Out:
# ⚠️ Skipping malformed line: ...
# Classical metrics: 100%|██████████| 218/218 [00:03<00:00, 63.54it/s]
# Computing BERTScore...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Saved detailed scores → /content/results/Llama-2-7b-chat-hf.csv
#
# === Mean ± 95% CI ===
# ROUGE-L   : 0.7848  (95% CI 0.7562–0.8135)
# BLEU      : 0.6801  (95% CI 0.6424–0.7177)
# Token-F1  : 0.8013  (95% CI 0.7759–0.8266)
# BERTScore : 0.9428 (95% CI 0.9376–0.9480)
